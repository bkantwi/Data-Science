# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame

# %%
import webbrowser
website='https://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %% [markdown]
# ### Copy the first few rows of the table

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost Tied[c]   Pct.  \
# 0     1        Dallas Cowboys    981  562   413   6 (0)  0.576
# 1     2     Green Bay Packers  1,435  799   598  38 (8)  0.572
# 2     3      Baltimore Ravens    451  256   194       1  0.569
# 3     4         Chicago Bears  1,469  793   634  42 (1)  0.556
# 4     5  New England Patriots    983  541   433   9 (0)  0.555
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1996  AFC North
# 3              1920  NFC North
# 4              1960   AFC East

# %%
# List the coloumn names
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied[c]', 'Pct.',
#        'First NFL season', 'Division'],
#       dtype='object')

# %%
# Call columns
nfl_frame['First NFL season']
# Out:
# 0    1960
# 1    1921
# 2    1996
# 3    1920
# 4    1960
# Name: First NFL season, dtype: int64

# %%
DataFrame(nfl_frame,columns=['Team','First NFL season'])
# Out:
#                    Team  First NFL season
# 0        Dallas Cowboys              1960
# 1     Green Bay Packers              1921
# 2      Baltimore Ravens              1996
# 3         Chicago Bears              1920
# 4  New England Patriots              1960

# %%
# What happens when we call a non existing column
DataFrame(nfl_frame, columns=['Team','First NFL season','Stadium'])
# Out:
#                    Team  First NFL season         Stadium
# 0        Dallas Cowboys              1960  Levi's Stadium
# 1     Green Bay Packers              1921  Levi's Stadium
# 2      Baltimore Ravens              1996  Levi's Stadium
# 3         Chicago Bears              1920  Levi's Stadium
# 4  New England Patriots              1960  Levi's Stadium

# %%
nfl_frame.head(2)
# Out:
#    Rank               Team     GP  Won  Lost Tied[c]   Pct.  First NFL season  \
# 0     1     Dallas Cowboys    981  562   413   6 (0)  0.576              1960
# 1     2  Green Bay Packers  1,435  799   598  38 (8)  0.572              1921
#
#     Division         Stadium
# 0   NFC East  Levi's Stadium
# 1  NFC North  Levi's Stadium

# %%
nfl_frame.tail(2)
# Out:
#    Rank                  Team     GP  Won  Lost Tied[c]   Pct.  \
# 3     4         Chicago Bears  1,469  793   634  42 (1)  0.556
# 4     5  New England Patriots    983  541   433   9 (0)  0.555
#
#    First NFL season   Division         Stadium
# 3              1920  NFC North  Levi's Stadium
# 4              1960   AFC East  Levi's Stadium

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost Tied[c]   Pct.  \
# 0     1        Dallas Cowboys    981  562   413   6 (0)  0.576
# 1     2     Green Bay Packers  1,435  799   598  38 (8)  0.572
# 2     3      Baltimore Ravens    451  256   194       1  0.569
# 3     4         Chicago Bears  1,469  793   634  42 (1)  0.556
# 4     5  New England Patriots    983  541   433   9 (0)  0.555
#
#    First NFL season   Division         Stadium
# 0              1960   NFC East  Levi's Stadium
# 1              1921  NFC North  Levi's Stadium
# 2              1996  AFC North  Levi's Stadium
# 3              1920  NFC North  Levi's Stadium
# 4              1960   AFC East  Levi's Stadium

# %%
nfl_frame.iloc[3]
# Out:
# Rank                             4
# Team                 Chicago Bears
# GP                           1,469
# Won                            793
# Lost                           634
# Tied[c]                     42 (1)
# Pct.                         0.556
# First NFL season              1920
# Division                 NFC North
# Stadium             Levi's Stadium
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost Tied[c]   Pct.  \
# 0     1        Dallas Cowboys    981  562   413   6 (0)  0.576
# 1     2     Green Bay Packers  1,435  799   598  38 (8)  0.572
# 2     3      Baltimore Ravens    451  256   194       1  0.569
# 3     4         Chicago Bears  1,469  793   634  42 (1)  0.556
# 4     5  New England Patriots    983  541   433   9 (0)  0.555
#
#    First NFL season   Division         Stadium
# 0              1960   NFC East  Levi's Stadium
# 1              1921  NFC North  Levi's Stadium
# 2              1996  AFC North  Levi's Stadium
# 3              1920  NFC North  Levi's Stadium
# 4              1960   AFC East  Levi's Stadium

# %%
nfl_frame['Stadium'] = np.arange(5)

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost Tied[c]   Pct.  \
# 0     1        Dallas Cowboys    981  562   413   6 (0)  0.576
# 1     2     Green Bay Packers  1,435  799   598  38 (8)  0.572
# 2     3      Baltimore Ravens    451  256   194       1  0.569
# 3     4         Chicago Bears  1,469  793   634  42 (1)  0.556
# 4     5  New England Patriots    983  541   433   9 (0)  0.555
#
#    First NFL season   Division  Stadium
# 0              1960   NFC East        0
# 1              1921  NFC North        1
# 2              1996  AFC North        2
# 3              1920  NFC North        3
# 4              1960   AFC East        4

# %%
## Add a series to a dataframe
stadiums = Series(["Levi's Stadium", "AT&T Stadium"], index=[5,0])

# %%
stadiums
# Out:
# 5    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
## how to input it into the dataframe
nfl_frame['Stadium'] = stadiums

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost Tied[c]   Pct.  \
# 0     1        Dallas Cowboys    981  562   413   6 (0)  0.576
# 1     2     Green Bay Packers  1,435  799   598  38 (8)  0.572
# 2     3      Baltimore Ravens    451  256   194       1  0.569
# 3     4         Chicago Bears  1,469  793   634  42 (1)  0.556
# 4     5  New England Patriots    983  541   433   9 (0)  0.555
#
#    First NFL season   Division       Stadium
# 0              1960   NFC East  AT&T Stadium
# 1              1921  NFC North           NaN
# 2              1996  AFC North           NaN
# 3              1920  NFC North           NaN
# 4              1960   AFC East           NaN

# %%
## delete a column
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost Tied[c]   Pct.  \
# 0     1        Dallas Cowboys    981  562   413   6 (0)  0.576
# 1     2     Green Bay Packers  1,435  799   598  38 (8)  0.572
# 2     3      Baltimore Ravens    451  256   194       1  0.569
# 3     4         Chicago Bears  1,469  793   634  42 (1)  0.556
# 4     5  New England Patriots    983  541   433   9 (0)  0.555
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1996  AFC North
# 3              1920  NFC North
# 4              1960   AFC East

# %% [markdown]
# ## Construct dataframe by passing in dictionaries

# %%
data = {'City':['SF', 'LA', 'NYC'], 'Population':[837000, 380000, 84000000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA      380000
# 2  NYC    84000000

# %% [markdown]
# ## More on creating dataframes

# %%
dataframesWebsite = 'https://pandas.pydata.org/pandas-docs/dev/reference/api/pandas.DataFrame.html'
webbrowser.open(dataframesWebsite)
# Out:
# True
